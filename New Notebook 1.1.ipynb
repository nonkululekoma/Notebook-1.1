# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nonkululeko Mahlangu**
#
#    Data Scientist in the making

# %% [markdown]
# *I am interested in Data Science because, I love the idea of taking raw data and turning it into a story and also teaching your brain new ways is very healthy. My motto is, be a posibilities student and I try as much as I can to do what ohters say is not possible to tap out of my comfort zone.*

# %% [markdown]
# ### My code will give the total of both numbers added together.

# %%
#2 added to 2 
2+2
# Out:
# 4

# %% [markdown]
# 1. Line number One
# 2. Line number Two
# 3. Line number Three
